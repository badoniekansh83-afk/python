# %%
class car:
    def blueprint(self,enigne,tyre,weight,year):
        self.engine=enigne
        self.tyre=tyre
        self.weight=weight
        self.year=year

    def display(self):
        print(self.engine,self.tyre,self.weight,self.year)

# %%
s1=car()
s1.blueprint(1001210,"mrf",900,2026)
s1.display()
# Out:
# 1001210 mrf 900 2026

# %%
class car:
    def dummy_mileage_kmpl(engine_l: float, weight_kg: float, tyre_in: float) -> float:
        mileage = 28 - 4 * engine_l - 0.006 * (weight_kg - 1000) - 0.7 * (tyre_in - 15)
        return max(5.0, mileage) 


    def city_highway_kmpl(engine_l: float, weight_kg: float, tyre_in: float) -> tuple[float, float, float]:
        base = dummy_mileage_kmpl(engine_l, weight_kg, tyre_in)
        city = 0.85 * base
        highway = 1.10 * base
        return base, city, highway



if __name__ == "__main__":
    E, W, T = 1.5, 1200, 16
    base, city, highway = city_highway_kmpl(E, W, T)
    print(f"Inputs: engine={E}L, weight={W}kg, tyre={T}in")
    print(f"Base mileage   : {base:.2f} km/L")
    print(f"City mileage   : {city:.2f} km/L")
    print(f"Highway mileage: {highway:.2f} km/L")
# Out:
# Inputs: engine=1.5L, weight=1200kg, tyre=16in
# Base mileage   : 20.10 km/L
# City mileage   : 17.09 km/L
# Highway mileage: 22.11 km/L

# %%
class performance:
    def mileage_check(engine_l: float, weight_kg: float, tyre_in: float) -> float:
        mileage = 28 - 4 * engine_l - 0.006 * (weight_kg - 1000) - 0.7 * (tyre_in - 15)
        return max(5.0, mileage) 
    def display(self):

# %%
class mileage:
    def mileage(self,engine, weight, tyre):
        base = 28 - 4*engine - 0.006*(weight - 1000) - 0.7*(tyre - 15)
        base = max(5, base)  
        city = 0.85 * base
        highway = 1.10 * base
        return base, city, highway
E = 1.5
W = 1200
T = 16
ml=mileage()

m1.mileage()
print("Inputs:", E, "L,", W, "kg,", T, "in")
print("Base mileage   :", round(base, 2), "km/L")
print("City mileage   :", round(city, 2), "km/L")
print("Highway mileage:", round(highway, 2), "km/L")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 W = 1200
#      10 T = 16
# ---> 11 mileage(base, city, highway = mileage(E, W, T))
#      12 print("Inputs:", E, "L,", W, "kg,", T, "in")
#      13 print("Base mileage   :", round(base, 2), "km/L")
#
# TypeError: mileage() takes no arguments
